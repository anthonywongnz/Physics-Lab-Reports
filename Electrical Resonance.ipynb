# %% [markdown]
# # Experiment 263: Electrical Resonance
# ### Aim
# To investigate the phenomenon of electrical resonance, plot an accurate resonance curve, and deduce values of circuit parameters.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(16,9))

#c=22 nF, r=0 ohms
f1=np.array([6.467, 8.513, 8.959, 9.499, 9.644, 9.83, 10.005, 10.209, 10.67, 11.173, 11.404, 11.611, 11.814, 12.023, 12.761, 13.44, 17.72])
v1=np.array([0.75, 1.5, 1.8, 2.25, 2.4, 2.55, 2.7, 2.85, 3, 2.85, 2.7, 2.55, 2.4, 2.25, 1.8, 1.5, 0.75])

#c=22 nF, r=100 ohms
f2=np.array([5.22, 7.551, 8.156, 8.675, 8.919, 9.159, 9.406, 9.669, 9.982, 10.67, 11.438, 11.812, 12.146, 12.478, 12.818, 13.182, 14.03, 15.156, 21.84])
v2=np.array([0.481, 0.962, 1.154, 1.346, 1.442, 1.538, 1.635, 1.731, 1.827, 1.923, 1.827, 1.731, 1.635, 1.538, 1.442, 1.346, 1.154, 0.962, 0.481])

#c=22 nF, r=200 ohms
f3=np.array([4.292, 6.738, 7.445, 8.081, 8.382, 8.686, 9.0001, 9.343, 9.748, 10.67, 11.72, 12.227, 12.692, 13.153, 13.635, 14.144, 15.354, 17.06, 26.36])
v3=np.array([0.354, 0.708, 0.849, 0.991, 1.061, 1.132, 1.203, 1.274, 1.344, 1.415, 1.344, 1.274, 1.203, 1.132, 1.061, 0.991, 0.849, 0.708, 0.354])

#c=100 nF, r=200 ohms
f4=np.array([1.382, 2.471, 2.849, 3.211, 3.394, 3.582, 3.782, 4.003, 4.279, 4.93, 5.698, 6.095, 6.455, 6.819, 7.2, 7.614, 8.593, 9.92, 17.71])
v4=np.array([0.489, 0.978, 1.174, 1.369, 1.467, 1.565, 1.663, 1.76, 1.858, 1.956, 1.858, 1.76, 1.663, 1.565, 1.467, 1.369, 1.174, 0.978, 0.489])

#c=9.7 nF, r=100 ohms
f5=np.array([15.874, 19.389, 20.158, 20.785, 21.072, 21.35, 21.627, 21.918, 22.261, 23.02, 23.793, 24.177, 24.507, 24.827, 25.159, 25.511, 26.313, 27.358, 33.24])
v5=np.array([0.459, 0.918, 1.102, 1.285, 1.377, 1.469, 1.561, 1.652, 1.744, 1.836, 1.744, 1.652, 1.561, 1.469, 1.377, 1.285, 1.102, 0.918, 0.459])


plt.semilogx(f1, v1, linestyle="-", marker="x", color="red", label="c=22$nF$, r=0$\Omega$")
plt.semilogx(f2, v2, linestyle="-", marker="x", color="green", label="c=22$nF$, r=100$\Omega$")
plt.semilogx(f3, v3, linestyle="-", marker="x", color="blue", label="c=22$nF$, r=200$\Omega$")
plt.semilogx(f4, v4, linestyle="-", marker="x", color="orange", label="c=100$nF$, r=200$\Omega$")
plt.semilogx(f5, v5, linestyle="-", marker="x", color="purple", label="c=9.7$nF$, r=100$\Omega$")

plt.legend(loc = 1, prop={'size':11})

plt.xlabel("Frequency, $f$ in $kHz$")
plt.ylabel("Voltage, $v$ in $Volts$")

plt.title("$v$ Against $f$")

plt.show()
