# %% [markdown]
# # Experiment 217: Viscosity and Critical Velocity of Water
# ### Aim
# To measure the viscosity of water and to find the critical Reynolds number when flow becomes turbulent.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(16,9))

Q=np.array([1.54E-06,1.53E-06,1.74E-06,1.90E-06,2.15E-06,2.32E-06,2.53E-06,2.63E-06,3.07E-06,3.18E-06,3.35E-06,3.32E-06,3.40E-06,3.54E-06,3.57E-06,3.68E-06])
p=np.array([563.4792901,612.907298,662.3353059,741.4201185,860.0473375,919.3609469,1028.102564,1117.072979,1295.013807,1403.755424,1472.954635,1532.268245,1571.810651,1611.353058,1641.009862,1650.895464])

Q_all=np.array([1.54E-06,1.53E-06,1.74E-06,1.90E-06,2.15E-06,2.32E-06,2.53E-06,2.63E-06,3.07E-06,3.18E-06,3.35E-06,3.32E-06,3.40E-06,3.54E-06,3.57E-06,3.68E-06,3.84E-06,4.10E-06,4.24E-06,4.61E-06,4.64E-06])
p_all=np.array([563.4792901,612.907298,662.3353059,741.4201185,860.0473375,919.3609469,1028.102564,1117.072979,1295.013807,1403.755424,1472.954635,1532.268245,1571.810651,1611.353058,1641.009862,1650.895464,1917.806707,2125.40434,2382.429981,2659.226825,2936.023669])

plt.plot(p, Q, linestyle="-", marker="o", color="green")
#plt.plot(p_all, Q_all, linestyle="-", marker="o", color="green")

(m,b) = np.polyfit(p,Q,1) 
line=m*p+b
plt.plot(p,line,linestyle="--")
print("The equation of the line of best fit is y = ", m, "x + ", b, sep="")

plt.xlabel("p")
plt.ylabel("Q")

plt.title("p Against $Q$")

plt.show()
# Out:
# The equation of the line of best fit is y = 1.9104465543245055e-09x + 4.847264706908959e-07
